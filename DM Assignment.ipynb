# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 140)
pd.set_option('display.max_rows', 1000)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Self\New folder\Assignment_PUN\DM Assignment Absenteeism at work\Absenteeism_at_work.csv',sep=';')

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (740, 21)

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week', 'Seasons', 'Transportation expense',
#        'Distance from Residence to Work', 'Service time', 'Age', 'Work load Average/day ', 'Hit target', 'Disciplinary failure',
#        'Education', 'Son', 'Social drinker', 'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index', 'Absenteeism time in hours'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                                   int64
# Reason for absence                   int64
# Month of absence                     int64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense               int64
# Distance from Residence to Work      int64
# Service time                         int64
# Age                                  int64
# Work load Average/day              float64
# Hit target                           int64
# Disciplinary failure                 int64
# Education                            int64
# Son                                  int64
# Social drinker                       int64
# Social smoker                        int64
# Pet                                  int64
# Weight                               int64
# Height                               int64
# Body mass index                      int64
# Absenteeism time in hours            int64
# dtype: object

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week     Seasons  Transportation expense  \
# count  740.000000          740.000000        740.000000       740.000000  740.000000              740.000000
# mean    18.017568           19.216216          6.324324         3.914865    2.544595              221.329730
# std     11.021247            8.433406          3.436287         1.421675    1.111831               66.952223
# min      1.000000            0.000000          0.000000         2.000000    1.000000              118.000000
# 25%      9.000000           13.000000          3.000000         3.000000    2.000000              179.000000
# 50%     18.000000           23.000000          6.000000         4.000000    3.000000              225.000000
# 75%     28.000000           26.000000          9.000000         5.000000    4.000000              260.000000
# ...

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  Transportation expense  Distance from Residence to Work  \
# 0  11                  26                 7                3        1                     289                               36
# 1  36                   0                 7                3        1                     118                               13
# 2   3                  23                 7                4        1                     179                               51
# 3   7                   7                 7                5        1                     279                                5
# 4  11                  23                 7                5        1                     289                               36
#
#    Service time  Age  Work load Average/day   Hit target  Disciplinary failure  Education  Son  Social drinker  Social smoker  Pet  \
# ...

# %% [markdown]
# Missing Value check

# %%
df.isnull().any()
# Out:
# ID                                 False
# Reason for absence                 False
# Month of absence                   False
# Day of the week                    False
# Seasons                            False
# Transportation expense             False
# Distance from Residence to Work    False
# Service time                       False
# Age                                False
# Work load Average/day              False
# Hit target                         False
# Disciplinary failure               False
# Education                          False
# Son                                False
# Social drinker                     False
# Social smoker                      False
# Pet                                False
# Weight                             False
# Height                             False
# Body mass index                    False
# Absenteeism time in hours          False
# dtype: bool

# %% [markdown]
# # Outlier

# %%
df.boxplot(figsize=(50,50))

# %% [markdown]
# # Outlier analysis for numerical features

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 13
fig_size[1] = 8.5
plt.rcParams["figure.figsize"] = fig_size
df.boxplot(column=['Transportation expense','Distance from Residence to Work', 'Service time', 'Age','Hit target'])

# %%
df.boxplot(column = ['Weight', 'Height', 'Body mass index','Absenteeism time in hours'])

# %%
df.boxplot(column=['Work load Average/day '])

# %% [markdown]
# Removing outliers

# %%
for i in ['Transportation expense','Service time','Age','Work load Average/day ','Hit target','Height',
'Absenteeism time in hours']:
    q75,q25 = np.percentile(df.loc[:,i],[75,25])
    iqr = q75-q25
    min = q25-1.5*iqr
    max = q75+1.5*iqr
    df.loc[df[i] < min,i] = min
    df.loc[df[i] > max,i] = max

# %% [markdown]
# EDA after data cleanup

# %%
df.boxplot(column = ['Weight', 'Height', 'Body mass index','Absenteeism time in hours'])

# %%
# From the EDA and problem statement file categorising the variables in two category " Continuos" and "Categorical"
continuous_vars = ['Distance from Residence to Work', 'Service time', 'Age', 'Work load Average/day ', 'Transportation expense',
       'Hit target', 'Weight', 'Height', 'Body mass index', 'Absenteeism time in hours']

categorical_vars = ['ID','Reason for absence','Month of absence','Day of the week',
                     'Seasons','Disciplinary failure', 'Education', 'Social drinker',
                     'Social smoker', 'Pet', 'Son']

# %% [markdown]
# # Feature Selection

# %%
##Correlation analysis for continuous variables
#Correlation plot
df_corr = df.loc[:,continuous_vars]
#Set the width and hieght of the plot
f, ax = plt.subplots(figsize=(10, 10))

#Generate correlation matrix
corr = df_corr.corr()

#Plot using seaborn library
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), 
            cmap=sns.diverging_palette(220, 50, as_cmap=True),
            square=True, ax=ax, annot = True)
plt.plot()
# Out:
# []

# %%
#Since weight and body mass index are 90 PERCENT corr
# Droping Weight which has redundant information

df = df.drop('Weight', axis = 1)

# %% [markdown]
# # Feature Scaling

# %%
continuous_vars = ['Distance from Residence to Work', 'Service time', 'Age', 'Work load Average/day ', 'Transportation expense',
       'Hit target', 'Height', 'Body mass index', 'Absenteeism time in hours']
for i in continuous_vars:
    if i == 'Absenteeism time in hours':
        continue
    sns.distplot(df[i],bins = 'auto')
    plt.title("Checking Distribution for Variable "+str(i))
    plt.ylabel("Density")
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Normalization to fit scewness 
for i in continuous_vars:
    if i == 'Absenteeism time in hours':
        continue
    df[i] = (df[i] - df[i].min())/(df[i].max()-df[i].min())

# %%
# Correlation Analysis between categorical and target varaibale
def relationship(a,b):
    df1 = df.groupby(a)[b].sum()
    df1 = df1.reset_index()
    df1[b] = df1[b]*100/sum(df[b])
    df1 = df1.sort_values(by=['Absenteeism time in hours'])
    print(df1)
    return df1.plot.barh(x=a,y=b)

# %%
relationship('Reason for absence','Absenteeism time in hours')
# Out:
#     Reason for absence  Absenteeism time in hours
# 15                  16                   0.160600
# 2                    3                   0.214133
# 16                  17                   0.214133
# 3                    4                   0.240899
# 14                  15                   0.428266
# 1                    2                   0.455032
# 4                    5                   0.508565
# 22                  24                   0.642398
# 7                    8                   0.856531
# 19                  21                   0.936831
# 8                    9                   1.552463
# 5                    6                   1.820128
# 11                  12                   2.087794
# 23                  25                   2.890792
# 6                    7                   3.024625
# 13                  14                   3.452891
# 0                    1                   3.613490
# 17                  18                   4.122056
# ...

# %%
relationship('Month of absence','Absenteeism time in hours')
# Out:
#     Month of absence  Absenteeism time in hours
# 0                  1                   5.353319
# 8                  9                   6.209850
# 11                12                   6.691649
# 7                  8                   7.093148
# 1                  2                   7.682013
# 9                 10                   8.083512
# 5                  6                   8.137045
# 4                  5                   8.244111
# 3                  4                   8.351178
# 10                11                   8.511777
# 6                  7                  11.643469
# 2                  3                  13.998929

# %%
relationship('Education','Absenteeism time in hours')
# Out:
#    Education  Absenteeism time in hours
# 3          4                   0.562099
# 1          2                   7.066381
# 2          3                   9.689507
# 0          1                  82.682013

# %%
relationship('Son','Absenteeism time in hours')
# Out:
#    Son  Absenteeism time in hours
# 3    3                   3.024625
# 4    4                   6.531049
# 1    1                  26.739829
# 2    2                  27.007495
# 0    0                  36.697002

# %%
relationship('Pet','Absenteeism time in hours')

# %%
relationship('Day of the week','Absenteeism time in hours')
# Out:
#    Day of the week  Absenteeism time in hours
# 3                5                  14.614561
# 4                6                  16.648822
# 1                3                  20.289079
# 2                4                  22.055675
# 0                2                  26.391863

# %% [markdown]
# #    Modelling

# %%
# Using train_test_split sampling function for test and train data split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( df.iloc[:, df.columns != 'Absenteeism time in hours'], df.iloc[:, 8], test_size = 0.20)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
# Building model on top of training dataset
fit_DT = DecisionTreeRegressor(max_depth = 2).fit(X_train,y_train)

# Calculating RMSE for training data to check for over fitting
pred_train = fit_DT.predict(X_train)
rmse_for_train = np.sqrt(mean_squared_error(y_train,pred_train))

# Calculating RMSE for test data to check accuracy
pred_test = fit_DT.predict(X_test)
rmse_for_test =np.sqrt(mean_squared_error(y_test,pred_test))

print("Root Mean Squared Error For Training data = "+str(rmse_for_train))
print("Root Mean Squared Error For Test data = "+str(rmse_for_test))
print("R^2 Score(coefficient of determination) = "+str(r2_score(y_test,pred_test)))
# Out:
# Root Mean Squared Error For Training data = 1.6221000885501635
# Root Mean Squared Error For Test data = 1.6366131623931839
# R^2 Score(coefficient of determination) = 0.9256775228688856
